# %%
! git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd yolov5/
% pip install -r requirements.txt

# %%
# !unzip -q /content/drive/MyDrive/Aquarium/dataset.zip -d ../

# %%
# !python train.py --img 312 --data custom_data.yaml --epochs 300 --batch-size 16 --bbox_interval 1 --weights 'yolov5s.pt'
# Out:
# ...
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=312, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.9.0+cu111 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...

# %%
from utils.plots import plot_results
plot_results('/content/yolov5/runs/train/exp/results.csv')
# ! python detect.py --source '/content/drive/MyDrive/Aquarium/test.mp4' --weights './runs/train/exp/weights/best.pt'

# %%
# !python detect.py --source '/content/drive/MyDrive/Aquarium/yt5s.com-Georgia Aquarium video loop.mp4' --weights './runs/train/exp/weights/last.pt'
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (2008/7005) /content/drive/MyDrive/Aquarium/yt5s.com-Georgia Aquarium video loop.mp4: 384x640 1 shark, Done. (0.027s)
# video 1/1 (2009/7005) /content/drive/MyDrive/Aquarium/yt5s.com-Georgia Aquarium video loop.mp4: 384x640 1 shark, Done. (0.027s)
# video 1/1 (2010/7005) /content/drive/MyDrive/Aquarium/yt5s.com-Georgia Aquarium video loop.mp4: 384x640 Done. (0.027s)
# video 1/1 (2011/7005) /content/drive/MyDrive/Aquarium/yt5s.com-Georgia Aquarium video loop.mp4: 384x640 Done. (0.027s)
# video 1/1 (2012/7005) /content/drive/MyDrive/Aquarium/yt5s.com-Georgia Aquarium video loop.mp4: 384x640 Done. (0.027s)
# video 1/1 (2013/7005) /content/drive/MyDrive/Aquarium/yt5s.com-Georgia Aquarium video loop.mp4: 384x640 Done. (0.027s)
# video 1/1 (2014/7005) /content/drive/MyDrive/Aquarium/yt5s.com-Georgia Aquarium video loop.mp4: 384x640 3 sharks, Done. (0.027s)
# ...
